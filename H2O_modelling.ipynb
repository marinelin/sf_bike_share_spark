# %% [markdown]
# ## Machine Learning Using H2O

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pysparkling import *
from h2o.automl import H2OAutoML
from h2o.persist import set_s3_credentials
import h2o
import os

# %%
sc = SparkContext.getOrCreate()
ss = SparkSession.builder.getOrCreate()
hc = H2OContext.getOrCreate(ss)
# Out:
# Connecting to H2O server at http://127.0.0.1:54323 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         08 secs
# H2O cluster timezone:       America/Los_Angeles
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.28.0.1
# H2O cluster version age:    30 days
# H2O cluster name:           sparkling-water-sunqingyi_local-1579217939131
# H2O cluster total nodes:    1
# H2O cluster free memory:    379.2 Mb
# H2O cluster total cores:    12
# H2O cluster allowed cores:  12
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:54323
# H2O connection proxy:       {'http': None, 'https': None}
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, Amazon S3, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.7.4 final
# --------------------------  ------------------------------------------------------------------
# Sparkling Water Context:
#  * Sparkling Water Version: 3.28.0.1-1-2.4
#  * H2O name: sparkling-water-sunqingyi_local-1579217939131
#  * cluster size: 1
#  * list of used nodes:
#   (executorId, host, port)
#   ------------------------
#   (driver,127.0.0.1,54323)
#   ------------------------
#
#   Open H2O Flow in browser: http://127.0.0.1:54323 (CMD + click in Mac OSX)

# %%
train = h2o.import_file("mytraindata.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
predictors = train.names[:]
responce = 'bikes_available'
predictors.remove(responce)
predictors.remove('C1')

# %%
predictors
# Out:
# ['station_id',
#  'hour',
#  'is_weekend',
#  'temp_float',
#  'rain_identifier',
#  'start_count',
#  'end_count',
#  'total_docks',
#  'population']

# %% [markdown]
# ### Deep Learning

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator
model_dl = H2ODeepLearningEstimator(variable_importances=True, 
                                    loss="Automatic",
                                    hidden=[7,2],
                                    epochs=0.7,
                                    nfolds=5,
                                    fold_assignment="Modulo")

# %%
model_dl.train(x=predictors,
               y=responce,
               training_frame=train)
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%

# %%
model_dl
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_model_python_1579217939639_1
#
#
# Status of Neuron Layers: predicting bikes_available, regression, gaussian distribution, Quadratic loss, 117 weights/biases, 6.6 KB, 199,686 training samples, mini-batch size 1
#      layer  units       type dropout l1 l2    mean_rate     rate_rms momentum  \
# 0        1     13      Input       0
# 1        2      7  Rectifier       0  0  0     0.156438     0.373435        0
# 2        3      2  Rectifier       0  0  0   0.00115459  0.000792882        0
# 3        4      1     Linear          0  0  0.000627632   0.00021298        0
#
#   mean_weight weight_rms mean_bias      bias_rms
# 0
# 1   0.0501587   0.327844  0.414674      0.205719
# 2   -0.193633   0.482805  0.983585      0.135764
# 3   -0.484794   0.147284     1.007  1.09713e-154
# ModelMetricsRegression: deeplearning
# ** Reported on train data. **
#
# MSE: 12.082342936581284
# RMSE: 3.4759664751808645
# MAE: 2.7805796626321215
# RMSLE: 0.40745076528107455
# Mean Residual Deviance: 12.082342936581284
#
# ModelMetricsRegression: deeplearning
# ** Reported on cross-validation data. **
#
# MSE: 11.390507309371314
# RMSE: 3.374982564306268
# MAE: 2.6840014633453397
# RMSLE: 0.3961692932581858
# Mean Residual Deviance: 11.390507309371314
#
# Cross-Validation Metrics Summary:
#                                  mean           sd  cv_1_valid  cv_2_valid  \
# 0                     mae   2.6840017   0.03323998   2.6436238   2.6965103
# 1  mean_residual_deviance   11.390509   0.22242215   11.095568  11.4660225
# 2                     mse   11.390509   0.22242215   11.095568  11.4660225
# 3                      r2   0.2350242  0.014466327   0.2550326  0.22531831
# 4       residual_deviance   11.390509   0.22242215   11.095568  11.4660225
# 5                    rmse   3.3748536  0.033002634    3.331001   3.3861516
# 6                   rmsle  0.39613122  0.006140951  0.38965577  0.40370247
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    2.705457   2.6544073   2.7200096
# 1    11.54045   11.224878   11.625622
# 2    11.54045   11.224878   11.625622
# 3  0.22365496  0.24587092  0.22524424
# 4    11.54045   11.224878   11.625622
# 5   3.3971238    3.350355   3.4096367
# 6   0.3987034   0.3899242  0.39867023
# Scoring History:
#                timestamp    duration   training_speed    epochs  iterations  \
# 0    2020-01-16 15:41:06   0.000 sec             None  0.000000           0
# 1    2020-01-16 15:41:06   2.093 sec   821318 obs/sec  0.072078           1
# 2    2020-01-16 15:41:06   2.273 sec  1018806 obs/sec  0.796555          11
#
#     samples  training_rmse  training_deviance  training_mae  training_r2
# 0       0.0            NaN                NaN           NaN          NaN
# 1   18069.0       3.557071          12.652753      2.760071     0.149499
# 2  199686.0       3.475966          12.082343      2.780580     0.187841
# Variable Importances:
#                        variable  relative_importance  scaled_importance  \
# 0                   total_docks             1.000000           1.000000
# 1                    station_id             0.567871           0.567871
# 2                     end_count             0.539404           0.539404
# 3                    population             0.478880           0.478880
# 4               is_weekend.True             0.429488           0.429488
# 5              is_weekend.False             0.414450           0.414450
# 6                   start_count             0.345790           0.345790
# 7          rain_identifier.true             0.316672           0.316672
# 8         rain_identifier.false             0.232141           0.232141
# 9                    temp_float             0.184454           0.184454
# 10                         hour             0.171531           0.171531
# 11       is_weekend.missing(NA)             0.000000           0.000000
# 12  rain_identifier.missing(NA)             0.000000           0.000000
#
#     percentage
# 0     0.213644
# 1     0.121322
# 2     0.115240
# 3     0.102310
# 4     0.091758
# 5     0.088545
# 6     0.073876
# 7     0.067655
# 8     0.049596
# 9     0.039407
# 10    0.036647
# 11    0.000000
# 12    0.000000

# %% [markdown]
# ### AutoML

# %%
model_automl = H2OAutoML(max_models = 10,
                         seed = 1,
                         nfolds = 5, 
                         max_runtime_secs=1000)

# %%
model_automl.train(x=predictors,
                   y=responce, 
                   training_frame=train)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(model_automl.leaderboard['model_id'].as_data_frame().iloc[:,0])

# %%
lb2 = model_automl.leaderboard
lb2
# Out:
# <table>
# <thead>
# <tr><th>model_id                        </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">   rmse</th><th style="text-align: right;">    mse</th><th style="text-align: right;">    mae</th><th style="text-align: right;">   rmsle</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoost_1_AutoML_20200116_161833</td><td style="text-align: right;">                 5.65176</td><td style="text-align: right;">2.37734</td><td style="text-align: right;">5.65176</td><td style="text-align: right;">1.82444</td><td style="text-align: right;">0.294152</td></tr>
# </tbody>
# </table>

# %%
h2o.get_model('XGBoost_1_AutoML_20200116_161833')
# Out:
# Model Details
# =============
# H2OXGBoostEstimator :  XGBoost
# Model Key:  XGBoost_1_AutoML_20200116_161833
#
#
# Model Summary:
#      number_of_trees
# 0              275.0
# ModelMetricsRegression: xgboost
# ** Reported on train data. **
#
# MSE: 4.93951995269894
# RMSE: 2.222503082719783
# MAE: 1.7094994363473002
# RMSLE: 0.2800047155276033
# Mean Residual Deviance: 4.93951995269894
#
# ModelMetricsRegression: xgboost
# ** Reported on cross-validation data. **
#
# MSE: 5.651764238637661
# RMSE: 2.3773439462218464
# MAE: 1.8244351430840293
# RMSLE: 0.29415201167491384
# Mean Residual Deviance: 5.651764238637661
#
# Cross-Validation Metrics Summary:
#                                 mean           sd cv_1_valid  cv_2_valid  \
# 0                     mae  1.8244352  0.017950913  1.8209916   1.8030126
# 1  mean_residual_deviance   5.651765   0.10939602   5.618396   5.5470715
# 2                     mse   5.651765   0.10939602   5.618396   5.5470715
# 3                      r2  0.6204209  0.007870346  0.6227754  0.62522185
# 4       residual_deviance   5.651765   0.10939602   5.618396   5.5470715
# 5                    rmse  2.3772552  0.022979572  2.3703156   2.3552222
# 6                   rmsle  0.2941436  0.002488697  0.2919073   0.2934045
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0   1.8462918      1.8389   1.8129802
# 1   5.7881436     5.74533   5.5598836
# 2   5.7881436     5.74533   5.5598836
# 3   0.6106221  0.61400735  0.62947774
# 4   5.7881436     5.74533   5.5598836
# 5   2.4058561    2.396942   2.3579404
# 6  0.29718494  0.29634392  0.29187733
# Scoring History:
#                 timestamp           duration  number_of_trees  training_rmse  \
# 0     2020-01-16 16:31:52  13 min 19.022 sec              0.0       9.234040
# 1     2020-01-16 16:31:54  13 min 20.519 sec              5.0       7.409142
# 2     2020-01-16 16:31:55  13 min 21.897 sec             10.0       6.016401
# 3     2020-01-16 16:31:57  13 min 23.324 sec             15.0       4.985211
# 4     2020-01-16 16:31:58  13 min 24.678 sec             20.0       4.256441
# 5     2020-01-16 16:32:00  13 min 26.157 sec             25.0       3.727734
# 6     2020-01-16 16:32:01  13 min 27.765 sec             30.0       3.361002
# 7     2020-01-16 16:32:03  13 min 29.329 sec             35.0       3.107720
# 8     2020-01-16 16:32:04  13 min 30.848 sec             40.0       2.937564
# 9     2020-01-16 16:32:06  13 min 32.494 sec             45.0       2.819138
# 10    2020-01-16 16:32:07  13 min 34.059 sec             50.0       2.747558
# 11    2020-01-16 16:32:09  13 min 35.903 sec             55.0       2.695811
# 12    2020-01-16 16:32:11  13 min 37.704 sec             60.0       2.658906
# 13    2020-01-16 16:32:13  13 min 39.527 sec             65.0       2.629458
# 14    2020-01-16 16:32:15  13 min 41.466 sec             70.0       2.604684
# 15    2020-01-16 16:32:17  13 min 43.358 sec             75.0       2.585441
# 16    2020-01-16 16:32:19  13 min 45.284 sec             80.0       2.564112
# 17    2020-01-16 16:32:21  13 min 47.160 sec             85.0       2.548403
# 18    2020-01-16 16:32:22  13 min 49.071 sec             90.0       2.538473
# 19    2020-01-16 16:32:25  13 min 51.158 sec             95.0       2.528142
#
#     training_mae  training_deviance
# 0       8.390619          85.267496
# 1       6.522079          54.895381
# 2       5.128018          36.197083
# 3       4.120590          24.852326
# 4       3.426050          18.117291
# 5       2.947659          13.896004
# 6       2.628137          11.296337
# 7       2.412894           9.657921
# 8       2.272391           8.629280
# 9       2.176334           7.947540
# 10      2.118668           7.549073
# 11      2.078128           7.267399
# 12      2.048883           7.069779
# 13      2.026198           6.914048
# 14      2.007477           6.784377
# 15      1.992334           6.684504
# 16      1.976139           6.574668
# 17      1.963937           6.494360
# 18      1.956092           6.443845
# 19      1.948000           6.391500
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#                  variable  relative_importance  scaled_importance  percentage
# 0             total_docks         4.512015e+06           1.000000    0.281913
# 1              station_id         3.669668e+06           0.813310    0.229282
# 2              temp_float         2.603438e+06           0.577001    0.162664
# 3                    hour         1.687513e+06           0.374004    0.105437
# 4              population         1.346360e+06           0.298394    0.084121
# 5        is_weekend.False         7.190099e+05           0.159355    0.044924
# 6             start_count         4.126857e+05           0.091464    0.025785
# 7         is_weekend.True         3.637305e+05           0.080614    0.022726
# 8               end_count         3.163671e+05           0.070117    0.019767
# 9   rain_identifier.false         2.806531e+05           0.062201    0.017535
# 10   rain_identifier.true         9.356838e+04           0.020738    0.005846

# %%
sc.stop()
